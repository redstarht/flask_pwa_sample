# %%
import os , sys

# print(os.path.abspath(__file__))

print(os.path.abspath(__name__))
# Out:
# c:\z\app\flask_pwa_sample\tests\__main__

# %%
glb = 0

def func1():
    glb = 1

def func2():
    global glb # この行をコメントアウト（コメント化）する
    glb = 5

print(glb) # 0が出力される
func1()
print(glb) # 0が出力される
func2()
print(glb) # 0が出力される
# Out:
# 0
# 0
# 5
